# %%
import random

# %%
num = random.randint(1,10)
guess = int(input("Guess a number between 1 and 10: "))
if guess == num:
    print("You guessed correctly!")
else:
    print("You guessed incorrectly. The correct number was", num)
# Out:
# Guess a number between 1 and 10: 10
# You guessed incorrectly. The correct number was 7
